# %% [markdown]
# **Useful Imports**

# %%
import nibabel as nb
import numpy as np
import matplotlib.pyplot as plt
import csv
import plotly.graph_objects as go

# %% [markdown]
# **Variable Declaration**

# %%
INFO = 1 # For debugging

# Change path to find nifti files on local computer
data = []
with open('scans.csv', newline='') as scanfile:
    reader = csv.DictReader(scanfile)
    for row in reader:
        dataRow = [ row['file_name'], float(row['rg_value']), [], 0, 0, 0, 0 ]
        data.append(dataRow)

# %% [markdown]
# **Extract Images**

# %%
idx = 0
for d in data:
    data[idx][2] = np.asarray(nb.load(d[0]).dataobj)
    idx += 1

# %% [markdown]
# **Plot Images**

# %%
slice = 40 # Adjust this to change slice plotted

# Print preview of 4 scans with the various receiver gain
fig, frame = plt.subplots(2, 2, figsize=(9,9))
frame[0, 0].imshow(np.rot90(data[0][2][:,slice,:]))
frame[0, 0].set_title("PDW scan with {} receiver gain".format(data[0][1]))

frame[1, 0].imshow(np.rot90(data[1][2][:,slice,:]))
frame[1, 0].set_title("PDW scan with {} receiver gain".format(data[1][1]))

frame[0, 1].imshow(np.rot90(data[2][2][:,slice,:]))
frame[0, 1].set_title("PDW scan with {} receiver gain".format(data[2][1]))

frame[1, 1].imshow(np.rot90(data[3][2][:,slice,:]))
frame[1, 1].set_title("PDW scan with {} receiver gain".format(data[3][1]))

fig.suptitle("Plot of slice " + str(slice) + " for the scans used for analysis")
plt.show()

# %%
idx = 0
for d in data:
    mean = 0
    maxI = d[2][0, 0, 0]
    minI = d[2][0, 0, 0]

    for slice in d[2]:
        for row in slice:
            mean += sum(row)/row.size
            localMax = row.max()
            localMin = row.min()
            if( maxI < localMax ):
                maxI = localMax
            if( minI >  localMin ):
                minI = localMin
    mean = mean / (data[idx][2].shape[0] * data[idx][2].shape[1])
    data[idx][3] = mean
    data[idx][4] = ((maxI + minI) / 2)
    data[idx][5] = maxI
    data[idx][6] = minI
    if(INFO): 
        print("RG = {} :: Mean = {}, Min/Max average = {}, Max = {}, Min = {}".format(data[idx][1], data[idx][3],data[idx][4], data[idx][5], data[idx][6]))
    idx += 1
# Out:
# RG = 101.0 :: Mean = 27419858.869795956, Min/Max average = 83818952.02319336, Max = 167571419.6279297, Min = 66484.41845703125
# RG = 101.0 :: Mean = 27395445.14427185, Min/Max average = 85882439.57519531, Max = 171691520.14160156, Min = 73359.0087890625
# RG = 50.8 :: Mean = 12738501.666218894, Min/Max average = 39465600.270996094, Max = 78902303.89160156, Min = 28896.650390625
# RG = 50.8 :: Mean = 12772867.263649674, Min/Max average = 39463311.12585449, Max = 78895320.3178711, Min = 31301.933837890625

# %% [markdown]
# **Plot Results**

# %%
avgData = [ [ 101, 0, 0, 0 ], [ 50.8, 0, 0, 0 ] ]

for d in data:
    if( d[1] == 101.0 ):
        avgData[0][1] += d[3]
        avgData[0][2] += d[4]
        avgData[0][3] += 1
    elif( d[1] == 50.8 ):
        avgData[1][1] += d[3]
        avgData[1][2] += d[4]
        avgData[1][3] += 1

idx = 0
for a in avgData:
    if( a[3] > 0 ):
        avgData[idx][1] = a[1]/a[3]
        avgData[idx][2] = a[2]/a[3]
    idx += 1

tableData = [ [], [], [] ]
for idx in range(1, len(avgData)):
    tableData[0].append((avgData[0][0]/avgData[idx][0]))
    tableData[1].append((avgData[0][1]/avgData[idx][1]))
    tableData[2].append((avgData[0][2]/avgData[idx][2]))

fig = go.Figure(data=[go.Table(header=dict(values=['Expected ratio (101 / f(RG))', 
                                                   'Experimental ratio accodring to mean calculation', 
                                                   'Experimental ratio accodring to min/max calculation']),
                cells=dict(values=tableData))])
fig.update_layout( title_text="Expected ratios vs experimental ratio of the receiver gain taking the reference receiver gain as 101", title_x=0.5 )
fig.show()

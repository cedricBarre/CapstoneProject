# %%
import nibabel as nb
import numpy as np
import matplotlib.pyplot as plt
import csv
import plotly.graph_objects as go
import PIL as ThePIL

# %%
img = np.asarray(nb.load('/home/cedric/Documents/Capstone/Brains/MTR_ratio_data/scans/scan_batch1/20220210_MCH_MTR_RG_002_1-02-1-PDw-flash_2019.nii.gz').dataobj)

# %%
slice = 45
fig = plt.figure(1)
pos = plt.imshow(np.rot90(img[:, slice, :]), vmax=1.5e8, vmin=0)
plt.colorbar(pos)

plt.savefig("/home/cedric/Documents/Capstone/MidProjectReport/figure1.jpg")
